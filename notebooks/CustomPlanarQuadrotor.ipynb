# %%
import sys
sys.path.append('../') 

from src.controllers import QuadrotorLQR
from src.plants import ClosedLoopPlanarQuadrotor
from src.visualizations import visualize_sim

# %%
clpqr = ClosedLoopPlanarQuadrotor(QuadrotorLQR)
# Out:
# ClosedLoopPlanarQuadrotor Instance
# ::ClosedLoopPlanarQuadrotor Context (of a Diagram)
# ---------------------------------------------------
# 6 total continuous states
# 6 total numeric parameters in 1 groups
#
# ::ClosedLoopPlanarQuadrotor::Quadrotor Context
# -----------------------------------------------
# Time: 0
# States:
#   6 continuous states
#     -1.118291213153327 -1.325127176495273 0.4931138103238139 -1.326973428085557 0.2039147757102915  1.126422367689105
#
#
# ::ClosedLoopPlanarQuadrotor::Setpoint Vector Context
# -----------------------------------------------------
# Time: 0
# Parameters:
#   1 numeric parameter groups with
#      6 parameters
#        0 0 0 0 0 0
#
# Total Stats: 6
# Current Mutable State: <pydrake.systems.framework.State object at 0x1874a5d70>
# Setpoint Mutable Context: ::ClosedLoopPlanarQuadrotor::Setpoint Vector Context
# -----------------------------------------------------
# Time: 0
# Parameters:
#   1 numeric parameter groups with
# ...

# %%
dt = 0.1

while(clpqr.time < 20): 
    clpqr.step(dt) 

print(clpqr.data_log)
visualize_sim(clpqr)
# Out:
# {'time': [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7, 0.7999999999999999, 0.8999999999999999, 0.9999999999999999, 1.0999999999999999, 1.2, 1.3, 1.4000000000000001, 1.5000000000000002, 1.6000000000000003, 1.7000000000000004, 1.8000000000000005, 1.9000000000000006, 2.0000000000000004, 2.1000000000000005, 2.2000000000000006, 2.3000000000000007, 2.400000000000001, 2.500000000000001, 2.600000000000001, 2.700000000000001, 2.800000000000001, 2.9000000000000012, 3.0000000000000013, 3.1000000000000014, 3.2000000000000015, 3.3000000000000016, 3.4000000000000017, 3.5000000000000018, 3.600000000000002, 3.700000000000002, 3.800000000000002, 3.900000000000002, 4.000000000000002, 4.100000000000001, 4.200000000000001, 4.300000000000001, 4.4, 4.5, 4.6, 4.699999999999999, 4.799999999999999, 4.899999999999999, 4.999999999999998, 5.099999999999998, 5.1999999999999975, 5.299999999999997, 5.399999999999997, 5.4999999999999964, 5.599999999999996, 5.699999999999996, 5.799999999999995, 5.89999999
# ...
